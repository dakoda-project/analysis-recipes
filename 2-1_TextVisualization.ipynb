# %% [markdown]
# # Text Visualization

# %%
from dakoda.corpus import DakodaCorpus
from dakoda.uima import load_dakoda_typesystem
from cas_visualizer.visualizer import SpanVisualizer
from IPython.display import display, HTML

# %%
wtld = DakodaCorpus("data/swiko_wtld/DaF")
doc = wtld.random_doc()

cas = doc.learner._view 
vis = SpanVisualizer(load_dakoda_typesystem())
vis.selected_span_type = SpanVisualizer.HIGHLIGHT
vis.add_type('Sentence', default_label = 'S', color="#DDDDDD")

html = vis.visualize(cas)
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #DDDDDD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ich finde wir nicht gehen in Deutschland weil ich nicht Deutsch mage .
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">S</span>
# </mark>
#
# <mark class="entity" style="background: #DDDDDD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aber ich finde das ist eine gute Idee für lernen English in Grande - Bretagne oder USA .
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">S</span>
# </mark>
#
# <mark class="entity" style="background: #DDDDDD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weil English ist mehr simple .
# ...

# %%
doc = wtld.random_doc()
cas = doc.learner._view 
vis_lemma = SpanVisualizer(load_dakoda_typesystem())
vis_lemma.selected_span_type = SpanVisualizer.UNDERLINE
vis_lemma.add_type(type_name = 'Lemma', feature_name = 'value', color="#FFA500")

html = vis_lemma.visualize(cas)
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# TypeNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 vis_lemma.selected_span_type = SpanVisualizer.UNDERLINE
#       5 vis_lemma.add_type(type_name = 'Lemma', feature_name = 'value', color="#FFA500")
# ----> 7 html = vis_lemma.visualize(cas)
#       8 display(HTML(html))
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/cas_visualizer/visualizer.py:100, in Visualizer.visualize(self, cas)
#      98     case _:
#      99         raise VisualizerException('cas cannot be None')
# --> 100 return self.render_visualization()
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/cas_visualizer/visualizer.py:156, in SpanVisualizer.render_visualization(self)
#     154     return self.parse_ents()
#     155 case SpanVisualizer.UNDERLINE:
# --> 156     return self.parse_spans()
#     157 case _:
# ...

# %%
doc = wtld.random_doc()
cas = doc.learner._view 
vis_lemma = SpanVisualizer(load_dakoda_typesystem())
vis_lemma.selected_span_type = SpanVisualizer.HIGHLIGHT
# full type name needed due to ambiguity with another 'POS' type
vis_lemma.add_type(type_name = 'de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS', feature_name = 'PosValue')

html = vis_lemma.visualize(cas)
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hallo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ITJ</span>
# </mark>
#
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">$,</span>
# </mark>
#
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     .
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">$.</span>
# </mark>
#
# ...

# %% [markdown]
# ## Dependencies

# %%
from spacy.displacy.render import DependencyRenderer 
from recipe_util import dep_to_dict

doc = wtld.random_doc()
sent = doc.learner.sentences[0]

struct = dep_to_dict(cas=doc.cas, span=sent.span, view_name='ctok')

# words = [
#     {'text': 'Hallo', 'tag': 'ITJ'},
#     {'text': ',', 'tag': '$,'},
#     {'text': 'ich', 'tag': 'PPER'},
#     {'text': 'heisse', 'tag': 'VVFIN'},
#     {'text': 'Maria', 'tag': 'NE'}
# ]

# arcs = [
#     {'start': 0, 'end': 1, 'label': 'punct', 'dir': 'left'},
#     {'start': 2, 'end': 4, 'label': 'nsubj', 'dir': 'left'},
#     {'start': 3, 'end': 4, 'label': 'cop', 'dir': 'left'},
#     {'start': 0, 'end': 4, 'label': 'parataxis', 'dir': 'left'}
# ]

renderer = DependencyRenderer(options={
    'compact': True, 
    'bg': '#f8f8f8', 
    'color': 'black', 
    'font': 'Arial'}
)
html = renderer.render([{"words": struct['words'], "arcs": struct['arcs']}])
# html = renderer.render([{"words": words, "arcs": arcs}])

display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a123af53b79c42058a90f2c608d543fe-0" class="displacy" width="2300" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: black; background: #f8f8f8; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PPER</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">finde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VVFIN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">der</tspan>
# ...

# %%
renderer = DependencyRenderer()
html = renderer.render([{"words": struct['words'], "arcs": struct['arcs']}])
# html = renderer.render([{"words": words, "arcs": arcs}])
svg = renderer.render_svg(render_id=1, words=struct['words'], arcs = struct['arcs'])

svg_html = f"""
<div style="width:400px; height:200px; overflow:auto;">
    <svg style="transform: scale(0.5); transform-origin: top left;">
        {svg}
    </svg>
</div>
"""
display(HTML(svg_html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1" class="displacy" width="2675" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PPER</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">finde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VVFIN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">der</tspan>
# ...
