# %% [markdown]
# # Text Visualization

# %%
from dakoda.corpus import DakodaCorpus, DakodaPublicCorpusName
from dakoda.uima import load_dakoda_typesystem
from cas_visualizer.visualizer import SpanVisualizer
from IPython.display import display, HTML

# %%
wtld = DakodaCorpus(DakodaPublicCorpusName.MERL_L2)
doc = wtld.random_doc()

view = doc.learner._view 
visualizer = SpanVisualizer(load_dakoda_typesystem())
visualizer.add_type(name = 'Stage', feature = 'name')

html = visualizer.visualize(view)
display(HTML(html))
# Out:
# [CACHE LOAD] Using cached corpus: MERL-L2
# [LOCAL LOAD] Loading corpus from: /Users/zesch/git/dakoda/analysis-recipes/.dakoda/corpora/MERL-L2
# <div class="spans" style="line-height: 2.5; direction: ltr">Wenn  ich  im  Ausland  leben
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     möchte
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VEND
#     </span>
# </span>
#
#
# </span>
#   ,
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     muss
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: lightgreen; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         INV
#     </span>
# </span>
#
#
# <span style="background: lightgreen; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         SEP
#     </span>
# </span>
#
#
# </span>
#   ich  meines  Erachtens  mit  den  Gebräuchen  des  fremden  Landes  im  Klare  sein  .  Meiner  festen  Überzeugung  nach
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     würden
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: lightgreen; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         INV
#     </span>
# </span>
#
#
# <span style="background: lightgreen; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         SEP
#     </span>
# </span>
#
#
# </span>
#   die  Ausländer  von  mir  erwarten  ,  dass  ich  mich  ihnen
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     anpasse
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VEND
#     </span>
# </span>
#
#
# </span>
#   .  Damit
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     bin
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         INV
#     </span>
# </span>
#
#
# </span>
#   ich  natürlich  einverstanden  ,  vorausgesetzt  dass  auch  ich  meine  Gewohnheiten  üben
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     kann
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VEND
#     </span>
# </span>
#
#
# </span>
#   .  Ich
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     würde
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: lightgreen; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         SEP
#     </span>
# </span>
#
#
# <span style="background: lightgreen; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         SVO
#     </span>
# </span>
#
#
# </span>
#   gerne  nach  Deutschland  fahren  .  Da  ich  die  Gebräuche  von  Deutschen  gut
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     kenne
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VEND
#     </span>
# </span>
#
#
# </span>
#   ,
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     würde
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         SEP
#     </span>
# </span>
