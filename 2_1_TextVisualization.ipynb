# %% [markdown]
# # Text Visualization

# %%
from dakoda.corpus import DakodaCorpus
from dakoda.uima import load_dakoda_typesystem
from cas_visualizer.visualizer import SpanVisualizer
from IPython.display import display, HTML

# %%
wtld = DakodaCorpus("data/WTLD")
doc = wtld.random_doc()

cas = doc.learner._view 
vis = SpanVisualizer(load_dakoda_typesystem())
vis.selected_span_type = SpanVisualizer.HIGHLIGHT
vis.add_type('Sentence', default_label = 'S', color="#DDDDDD")

html = vis.visualize(cas)
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 wtld = DakodaCorpus("data/WTLD")
# ----> 2 doc = wtld.random_doc()
#       4 cas = doc.learner._view
#       5 vis = SpanVisualizer(load_dakoda_typesystem())
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/dakoda/corpus.py:203, in random_doc(self)
#     201 if isinstance(key, Predicate):
#     202     return self.__getitem__(self._query(key))
# --> 203 elif isinstance(key, str) or isinstance(key, Path):
#     204     return self._get_by_path(key)
#     205 elif isinstance(key, int):
#
# ValueError: No documents in the corpus.

# %%
doc = wtld.random_doc()
cas = doc.learner._view 
vis_lemma = SpanVisualizer(load_dakoda_typesystem())
vis_lemma.selected_span_type = SpanVisualizer.UNDERLINE
vis_lemma.add_type(type_name = 'Lemma', feature_name = 'value', color="#FFA500")

html = vis_lemma.visualize(cas)
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 doc = wtld.random_doc()
# ----> 2 cas = doc.learner._view
#       3 vis_lemma = SpanVisualizer(load_dakoda_typesystem())
#       4 vis_lemma.selected_span_type = SpanVisualizer.UNDERLINE
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/dakoda/corpus.py:65, in learner(self)
#      60 @property
#      61 def text(self) -> str:
#      62     """Get the raw text content of the document, i.e. the text the learner produced.
#      63
#      64     Returns:
# ---> 65         The document's text.
#      66     """
#      67     return self.cas.sofa_string
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/dakoda/corpus.py:61, in view(self, view_name)
#      57     if corpus is None and cas is None:
#      58         raise ValueError("Cas and Corpus cannot be None.")
#      60 @property
# ---> 61 def text(self) -> str:
#      62     """Get the raw text content of the document, i.e. the text the learner produced.
#      63
#      64     Returns:
#      65         The document's text.
#      66     """
#      67     return self.cas.sofa_string
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/dakoda/corpus.py:42, in cas(self)
#      36 class DakodaDocument:
#      37     """Represents a single document in a Dakoda corpus.
#      38
#      39     Provides access to document data, i.e. text, annotations and metadata.
#      40
#      41     Args:
# ---> 42         cas: Optional CAS object containing document annotations.
#      43         id: Unique identifier for the document.
#      44         corpus: Parent corpus containing this document.
#      45
#      46     Raises:
#      47         ValueError: If both cas and corpus are None.
#      48     """
#      49     def __init__(
#      50         self, cas: Cas | None, id: str | None = None, corpus: DakodaCorpus | None = None
#      51     ):
#      52         self._cas = cas
#
# File ~/git/dakoda/analysis-recipes/.venv/lib/python3.11/site-packages/dakoda/uima.py:17, in load_cas_from_file(path, ts)
#      16 def load_cas_from_file(path, ts):
# ---> 17     with open(path, "rb") as f:
#      18         return cassis.load_cas_from_xmi(f, typesystem=ts)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/WTLD/SWI03_fD_Mo103_p.xmi'

# %%
doc = wtld.random_doc()
cas = doc.learner._view 
vis_lemma = SpanVisualizer(load_dakoda_typesystem())
vis_lemma.selected_span_type = SpanVisualizer.HIGHLIGHT
# full type name needed due to ambiguity with another 'POS' type
vis_lemma.add_type(type_name = 'de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS', feature_name = 'PosValue')

html = vis_lemma.visualize(cas)
display(HTML(html))
# Out:
# <div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Halb
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         CARD
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Personnen
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         NN
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     in
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         APPR
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Schweiz
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         NE
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     haben
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VAFIN
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     ein
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ART
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Tiere
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         NN
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     .
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         $.
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Eine
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ART
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Katze
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         NN
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Kaugt
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         VVFIN
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     400
#
# <span style="background: lightgreen; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: lightgreen; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: lightgreen; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         CARD
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline
