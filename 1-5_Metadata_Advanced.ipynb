# %% [markdown]
# # Advanced Metadata

# %%
from dakoda.corpus import DakodaCorpus, DakodaPublicCorpusName, MetaData

merlin = DakodaCorpus(DakodaPublicCorpusName.MERL_L2)
doc = merlin.random_doc()
meta = doc.meta

for meta_var in meta.iter_flat():
    print(meta_var)
# Out:
# [CACHE LOAD] Using cached corpus: MERL-L2
# [LOCAL LOAD] Loading corpus from: /Users/zesch/git/dakoda/analysis-recipes/.dakoda/corpora/MERL-L2
# ('learner_language_proficiency_score', 'notAvailable')
# ('learner_language_proficiency_cefrMax', 'notAvailable')
# ('learner_language_proficiency_cefrMin', 'notAvailable')
# ('learner_language_proficiency_cTestCefrMax', 'notAvailable')
# ('learner_language_proficiency_cTestCefrMin', 'notAvailable')
# ('learner_language_proficiency_cTestLevelDetail', 'notAvailable')
# ('learner_language_proficiency_cTestPercent', 'notAvailable')
# ('learner_language_proficiency_cTestType', 'notAvailable')
# ('learner_language_proficiency_estimateMax', 'notAvailable')
# ('learner_language_proficiency_estimateMin', 'notAvailable')
# ('learner_language_proficiency_selfAssessment', 'notAvailable')
# ('learner_language_proficiency_assignmentInstrument', 'notAvailable')
# ('learner_language_proficiency_assignmentMethod', 'notAvailable')
# ('learner_language_proficiency_documentation', 'notAvailable')
# ('learner_language_proficiency_score', 'notAvailable')
# ('learner_language_proficiency_cefrMax', 'notAvailable')
# ('learner_language_proficiency_cefrMin', 'notAvailable')
# ('learner_language_proficiency_cTestCefrMax', 'notAvailable')
# ('learner_language_proficiency_cTestCefrMin', 'notAvailable')
# ('learner_language_proficiency_cTestLevelDetail', 'notAvailable')
# ('learner_language_proficiency_cTestPercent', 'notAvailable')
# ('learner_language_proficiency_cTestType', 'notAvailable')
# ('learner_language_proficiency_estimateMax', 'B1')
# ('learner_language_proficiency_estimateMin', 'B1')
# ('learner_language_proficiency_selfAssessment', 'notAvailable')
# ('learner_language_proficiency_assignmentInstrument', 'notAvailable')
# ('learner_language_proficiency_assignmentMethod', 'notAvailable')
# ('learner_language_proficiency_documentation', 'notAvailable')

# %%
meta.print_schema_tree()
# Out:
# corpus
#   administrative
#     corpus_admin_acronym
#     corpus_admin_name
#     corpus_admin_author
#     corpus_admin_availability
#     corpus_admin_citationDocument
#     corpus_admin_citeAs
#     corpus_admin_contactMail
#     corpus_admin_contributor_dkd
#     corpus_admin_contributor_orig
#     corpus_admin_dateOfPublication
#     corpus_admin_documentation
#     corpus_admin_fileFormat
#     corpus_admin_licence
#     corpus_admin_licenceFulltext
#     corpus_admin_licenceUrl
#     corpus_admin_otherVersions
#     corpus_admin_pid_dkd
#     corpus_admin_pid_orig
#     corpus_admin_refArticle
#     corpus_admin_referencesOther
#     corpus_admin_researchPaper
#     corpus_admin_URL_download
#     corpus_admin_URLquery
#     corpus_admin_version_orig
#   design
#     corpus_design_description
#     corpus_design_designType
#     corpus_design_group
#     corpus_design_isComparableDataIncluded
#     corpus_design_l1Languages
#     corpus_design_l1Type
#     corpus_design_size
#       value
#       unit
#     corpus_design_targetLanguage
#     corpus_design_targetLanguageType
#     corpus_design_timeOfDataCollection
#   proficiency
#     corpus_proficiency_assignmentMethod
#     corpus_proficiency_isAssignmentAvailable
#     corpus_proficiency_learner_AssignmentInstrument
#     corpus_proficiency_levelMax
#     corpus_proficiency_levelMin
#     corpus_proficiency_textAssignmentInstrument
#     corpus_proficiency_textAutomaticAssignmentInstrument
#   project
#     corpus_project_contact_orig
#     corpus_project_duration_dkd
#     corpus_project_duration_orig
#     corpus_project_head_dkd
#     corpus_project_head_orig
#     corpus_project_institution_dkd
#     corpus_project_institution_orig
#     corpus_project_name_dkd
#     corpus_project_name_orig
#     corpus_project_type_dkd
#     corpus_project_type_orig
#     corpus_project_URL_dkd
#     corpus_project_URL_orig
#   subcorpus
#     corpus_subcorpus_signet
#     corpus_subcorpus_sizeLearners
#     corpus_subcorpus_sizeTexts
#     corpus_subcorpus_sizeTokens
#     corpus_subcorpus_targetLanguage
#     corpus_subcorpus_size
#       value
#       unit
#   annotation
#     corpus_annotation_hasBorrowedAnnotation_orig
#     corpus_annotation_hasErrorAnnotation_orig
#     corpus_annotation_hasTargetHypotheses_orig
# production_setting
#   production_setting_schoolGrade
#   productionSetting_educationalStage
#   productionSetting_languageTest
#   productionSetting_languageCourseLevel
#   productionSetting_naturalistic
#   productionSetting_collectedInResearchProject
#   productionSetting_setting
#   productionSetting_schoolGrade
# task
#   task_id
#   task_id_orig
#   task_title
#   task_comparison
#   task_comparison_otherCorpora
#   task_description
#   task_descriptionDetailed
#   task_durationMinutes
#   task_instructions
#   task_isDurationLimited
#   task_levelMax
#   task_levelMin
#   task_assessed
#   task_officialLanguageTest
#   task_officialLanguageTestSpecific
#   task_options
#   task_stimulusOffered
#   task_stimulusType
#   interaction
#     task_interaction_conceptualMode
#     task_interaction_ExpectedRhetoricalFunctions
#     task_interaction_formality
#     task_interaction_mode
#     task_interaction_participantsL1L2Interaction
#     task_interaction_participants
#     task_interaction_type
# learner
#   learner_id
#   learner_id_orig
#   learner_lCount
#   learner_multipleL1
#   learner_textCount
#   learner_note
#   sociodemographic
#     learner_socio_ageProduction
#     learner_socio_birthplace
#     learner_socio_country
#     learner_socio_educationalBackground
#     learner_socio_gender
#     learner_socio_majorSubject
#     learner_socio_profession
#     learner_socio_schoolGrade
#   language
#     learner_language_iso639_3
#       name_de
#       name_en
#       iso_code_639_3
#       group
#     learner_language_status
#     learner_language_IsTarget
#     learner_language_dominantWordOrder
#     learner_language_group
#     learner_language_isSpokenHome
#     learner_language_isSpokenSchool
#     learner_language_parentL1
#     exposure
#       learner_language_exposure_onset
#       learner_language_exposure_onset_group
#       learner_language_exposure_durationOfInstruction
#       learner_language_exposure_durationOfUse
#       learner_language_exposure_input
#       learner_language_exposure_institution
#       learner_language_exposure_monthsSpentEnvironment
#       learner_language_exposure_learningContext
#       learner_language_exposure_placeAcquisition
#       learner_language_exposure_wasInEnvironment
#       learner_language_exposure_wasInstructed
#       learner_language_WasInstructed
#     proficiency
#       learner_language_proficiency_score
#       learner_language_proficiency_cefrMax
#       learner_language_proficiency_cefrMin
#       learner_language_proficiency_cTestCefrMax
#       learner_language_proficiency_cTestCefrMin
#       learner_language_proficiency_cTestLevelDetail
#       learner_language_proficiency_cTestPercent
#       learner_language_proficiency_cTestType
#       learner_language_proficiency_estimateMax
#       learner_language_proficiency_estimateMin
#       learner_language_proficiency_selfAssessment
#       learner_language_proficiency_assignmentInstrument
#       learner_language_proficiency_assignmentMethod
#       learner_language_proficiency_documentation
# text
#   text_file
#   text_id
#   text_ID_orig
#   text_language
#   text_longitudinalOrder
#   text_timeOfCreation
#   text_tokenCount
#   text_clauseCount
#   text_topicAutom
#   text_note
#   learner
#     text_learner_ageProduction
#     text_learner_ageProductionAggregated
#     text_learner_role
#   proficiency
#     text_proficiency_assignmentInstrument
#     text_proficiency_assignmentMethod
#     text_proficiency_cefrMax
#     text_proficiency_cefrMin
#     text_proficiency_cefrAutomMax
#     text_proficiency_cefrAutomMin
#     text_proficiency_documentation
#     text_proficiency_officialLanguageTestingScore
#     text_proficiency_score
#   annotation
#     text_annotation_borrowed_orig
#     text_annotation_hasErrorAnnotation_orig
#     text_annotation_hasTargetHypotheses
#     text_annotation_hasBorrowedAnnotation_orig
#     text_annotation_hasTargetHypotheses_orig
# target_hypothesis
#   targetHypothesis_automatic
#   targetHypothesis_corrected
#   targetHypothesis_documentation
#   targetHypothesis_evaluation
#   targetHypothesis_tool
#   targetHypothesis_toolVersion
# annotation
#   annotation_automatic
#   annotation_corrected
#   annotation_documentation
#   annotation_evaluation
#   annotation_note
#   annotation_tool
#   annotation_toolVersion
#   annotation_modelVersion
#   annotation_type
# annotator
#   annotator_id
#   annotator_L1
#   annotator_L2
#   annotator_note
#   annotator_targetLanguageCompetence
#   annotator_type

# %%
for lang in meta.learner.language:
    status = lang.learner_language_status # LangStatus (e.g., L1, L2, etc.)
    lang_code = lang.learner_language_iso639_3 # Lingua object
    if "L1" in str(status):
        print(f"L1 Language: {lang_code.iso_code_639_3}")
